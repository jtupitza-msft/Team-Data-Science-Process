# %% [markdown]
# ## Create an End-to-End Pipeline using Azure Machine Learning

# %% [markdown]
# ### Connect to an Azure Machine Learning Workspace

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.20.0 to work with mlops-aml-ws

# %% [markdown]
# ### Prepare the Training Data
# Local data files can be used to train a model, but when running training workloads on cloud-based compute, it makes more sense to store the data centrally in the cloud and then ingest it wherever the training script happens to be running.
#
# Here the training data is uploaded to a *datastore* and then a *dataset* is defined. For simplicity, the data is uploaded to the *default* datastore for your Azure Machine Learning workspace. In production, a datastore that references an existing cloud data storage location would be registered (e.g., a Data Lake). A *tabular* dataset is then created using the existing CSV files.

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'],
                            target_path='diabetes-data/', overwrite=True, show_progress=True)

    # Create a tabular dataset from the path on the datastore
    tab_ds = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_ds = tab_ds.register(workspace=ws, name='diabetes dataset',
                                 description='diabetes data',
                                 tags = {'format':'CSV'}, create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ### Create Scripts for Pipeline Steps
# - Create a folder dedicated to holding the scripts for each pipeline step
# - For the first pipeline step, generate a script that trains the machine learning model
# - For the second pipeline step, generate a script that registers the machine learning model

# %%
# Create a folder for the pipeline step files
import os

experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run
import argparse
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--output_folder', type=str, dest='output_folder', default="diabetes_model", help='output folder')
args = parser.parse_args()
output_folder = args.output_folder

# Get the experiment run context
run = Run.get_context()

# load the diabetes data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['diabetes_train'].to_pandas_dataframe()

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
os.makedirs(output_folder, exist_ok=True)
output_path = output_folder + "/model.pkl"
joblib.dump(value=model, filename=output_path)

run.complete()
# Out:
# Overwriting diabetes_pipeline/train_diabetes.py

# %%
# %%writefile $experiment_folder/register_diabetes.py
# Import libraries
import argparse
import joblib
from azureml.core import Workspace, Model, Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--model_folder', type=str, dest='model_folder', default="diabetes_model", help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# load the model
print("Loading model from " + model_folder)
model_file = model_folder + "/model.pkl"
model = joblib.load(model_file)

Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'})

run.complete()
# Out:
# Overwriting diabetes_pipeline/register_diabetes.py

# %% [markdown]
# ### Prepare a Compute Environment

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "train-cluster"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
    
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2'
                                                               , max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
        
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# ### Define a Run Configuration
# The compute requires a Python environment with the necessary package dependencies installed

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','pandas'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment (just in case you want to use it again)
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and Run a Pipeline
#
# First you need to define the steps for the pipeline, and any data references that need to passed between them. In this case, the first step must write the model to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used to pass data from the output of one pipeline step to the input of another, creating a dependency between them. You'll create one and use it as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so your code can access the datastore location referenced by the data reference.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
model_folder = PipelineData("model_folder", datastore=ws.get_default_datastore())

estimator = Estimator(source_directory=experiment_folder,
                        compute_target = pipeline_cluster,
                        environment_definition=pipeline_run_config.environment,
                        entry_script='train_diabetes.py')

# Step 1, run the estimator to train the model
train_step = EstimatorStep(name = "Train Model",
                           estimator=estimator, 
                           estimator_entry_script_arguments=['--output_folder', model_folder],
                           inputs=[diabetes_ds.as_named_input('diabetes_train')],
                           outputs=[model_folder],
                           compute_target = pipeline_cluster,
                           allow_reuse = True)

# Step 2, run the model registration script
register_step = PythonScriptStep(name = "Register Model",
                                source_directory = experiment_folder,
                                script_name = "register_diabetes.py",
                                arguments = ['--model_folder', model_folder],
                                inputs=[model_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# 'Estimator' is deprecated. Please use 'ScriptRunConfig' from 'azureml.core.script_run_config' with your own defined environment or an Azure ML curated environment.
# Pipeline steps defined

# %% [markdown]
# ### Build the Pipeline from the Steps, and then Run it as an AML Experiment
# > **Note**: This will take a while. The training cluster must be started and configured with the Python environment before the scripts can be run. This is a good time for a coffee break!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

# Construct the pipeline
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace = ws, name = 'diabetes-training-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Train Model [0ef6bb17][6ef40495-9929-4f1c-abec-b3dcef47bd94], (This step will run and generate new outputs)
# Created step Register Model [1c29e350][684f2a55-bea4-471c-b5fd-c98d4aaca80b], (This step will run and generate new outputs)
# Submitted PipelineRun 139fbc05-bf77-4cc6-9edd-24f76c3d08e5
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/139fbc05-bf77-4cc6-9edd-24f76c3d08e5?wsid=/subscriptions/49c8fb06-83d0-410a-81dd-c687e23bd829/resourcegroups/mlops-rg/workspaces/mlops-aml-ws
# Pipeline submitted for execution.
# PipelineRunId: 139fbc05-bf77-4cc6-9edd-24f76c3d08e5
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/139fbc05-bf77-4cc6-9edd-24f76c3d08e5?wsid=/subscriptions/49c8fb06-83d0-410a-81dd-c687e23bd829/resourcegroups/mlops-rg/workspaces/mlops-aml-ws
# PipelineRun Status: Running
#
#
# StepRunId: a659116e-d4b6-4522-afd8-cfd77f667bbf
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/a659116e-d4b6-4522-afd8-cfd77f667bbf?wsid=/subscriptions/49c8fb06-83d0-410a-81dd-c687e23bd829/resourcegroups/mlops-rg/workspaces/mlops-aml-ws
# StepRun( Train Model ) Status: NotStarted
# StepRun( Train Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt
# ========================================================================================================================
# 2021-04-07T20:31:22Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/mounts/workspaceblobstore
# 2021-04-07T20:31:22Z Starting output-watcher...
# 2021-04-07T20:31:22Z IsDedicatedCompute == False, starting polling for Low-Pri Preemption
# 2021-04-07T20:31:23Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-04-07T20:31:23Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_9bc95d0e9c4578baaca711aceb5ccff2
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# 5f63e2c14d66: Pulling fs layer
# 4679c43c5f7f: Pulling fs layer
# 3d09b63eb779: Pulling fs layer
# 2d728f7708e1: Pulling fs layer
# a21fdaa3c858: Pulling fs layer
# 87f59e73a0fc: Pulling fs layer
# 3edc9d7bb8cb: Pulling fs layer
# 7615bf3653fe: Pulling fs layer
# ddc2ac754537: Pulling fs layer
# 05895bb28c18: Waiting
# baf7ab26f516: Waiting
# d54d011de0e3: Waiting
# 181182e3c9cf: Waiting
# d584ef274e55: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# 5f63e2c14d66: Waiting
# 4679c43c5f7f: Waiting
# 3d09b63eb779: Waiting
# 2d728f7708e1: Waiting
# a21fdaa3c858: Waiting
# 87f59e73a0fc: Waiting
# 3edc9d7bb8cb: Waiting
# 7615bf3653fe: Waiting
# ddc2ac754537: Waiting
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# d887158cc58c: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# 5f63e2c14d66: Verifying Checksum
# 5f63e2c14d66: Download complete
# 4679c43c5f7f: Verifying Checksum
# 4679c43c5f7f: Download complete
# 3d09b63eb779: Verifying Checksum
# 3d09b63eb779: Download complete
# 2d728f7708e1: Verifying Checksum
# 2d728f7708e1: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# 87f59e73a0fc: Verifying Checksum
# 87f59e73a0fc: Download complete
# 3edc9d7bb8cb: Verifying Checksum
# 3edc9d7bb8cb: Download complete
# 7615bf3653fe: Verifying Checksum
# 7615bf3653fe: Download complete
# ddc2ac754537: Verifying Checksum
# ddc2ac754537: Download complete
# a21fdaa3c858: Verifying Checksum
# a21fdaa3c858: Download complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# 5f63e2c14d66: Pull complete
# 4679c43c5f7f: Pull complete
# 3d09b63eb779: Pull complete
# 2d728f7708e1: Pull complete
# a21fdaa3c858: Pull complete
# 87f59e73a0fc: Pull complete
# 3edc9d7bb8cb: Pull complete
# 7615bf3653fe: Pull complete
# ddc2ac754537: Pull complete
# Digest: sha256:5370c3a5a19ba9380083203765332516c53c51d4effd98ff898529ba91e83d1c
# Status: Downloaded newer image for jtupitzaamlcr.azurecr.io/azureml/azureml_9bc95d0e9c4578baaca711aceb5ccff2:latest
# jtupitzaamlcr.azurecr.io/azureml/azureml_9bc95d0e9c4578baaca711aceb5ccff2:latest
# 2021-04-07T20:32:25Z Check if container a659116e-d4b6-4522-afd8-cfd77f667bbf already exist exited with 0,
#
# c3db15c881b77a0434b9fca51da66ebf4190d27bd2593d323e020ac04d3e6a21
# 2021-04-07T20:32:34Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-04-07T20:32:34Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-fcd95f47d2f4a507de874c9921e52892-842030ad22513a09-01 -sshRequired=false]
# 2021/04/07 20:32:34 Starting App Insight Logger for task:  containerSetup
# 2021/04/07 20:32:34 Version: 3.0.01544.0003 Branch: .SourceBranch Commit: 14e0b35
# 2021/04/07 20:32:34 Entered ContainerSetupTask - Preparing infiniband
# 2021/04/07 20:32:34 Starting infiniband setup
# 2021/04/07 20:32:34 VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/04/07 20:32:34 VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-04-07T20:32:34Z VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/04/07 20:32:34 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/04/07 20:32:34 Not setting up Infiniband in Container
# 2021/04/07 20:32:34 Not setting up Infiniband in Container
# 2021-04-07T20:32:34Z Not setting up Infiniband in Container
# 2021/04/07 20:32:34 sshd inside container not required for job, skipping setup.
# 2021/04/07 20:32:34 All App Insights Logs was send successfully
# 2021/04/07 20:32:34 App Insight Client has already been closed
# 2021/04/07 20:32:34 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-04-07T20:32:34Z Starting docker container succeeded.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/04/07 20:32:41 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/04/07 20:32:41 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-04-07T20:32:41.977521] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError', 'UserExceptions:context_managers.UserExceptions'], invocation=['train_diabetes.py', '--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/mounts/workspaceblobstore/azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/model_folder'])
# Script type = None
# [2021-04-07T20:32:43.561448] Entering Run History Context Manager.
# [2021-04-07T20:32:44.300439] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/mounts/workspaceblobstore/azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf
# [2021-04-07T20:32:44.300754] Preparing to call script [train_diabetes.py] with arguments:['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/mounts/workspaceblobstore/azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/model_folder']
# [2021-04-07T20:32:44.300808] After variable expansion, calling script [train_diabetes.py] with arguments:['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/mounts/workspaceblobstore/azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/model_folder']
#
# Loading Data...
# 2021/04/07 20:32:46 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# Training a decision tree model
# Accuracy: 0.9006666666666666
# AUC: 0.886078007363292
#
#
# [2021-04-07T20:32:59.597517] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.15256738662719727 seconds
# [2021-04-07T20:32:59.980115] Finished context manager injector.
# 2021/04/07 20:33:05 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# 2021/04/07 20:33:05 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 2
# FilteredData: 0.
# 2021/04/07 20:33:05 Process Exiting with Code:  0
#
# Streaming azureml-logs/75_job_post-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt
# ===============================================================================================================
# [2021-04-07T20:33:06.168884] Entering job release
# [2021-04-07T20:33:07.311707] Starting job release
# [2021-04-07T20:33:07.312610] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 334
# [2021-04-07T20:33:07.313518] job release stage : upload_datastore starting...
# [2021-04-07T20:33:07.316029] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-04-07T20:33:07.323184] job release stage : copy_batchai_cached_logs starting...
# [2021-04-07T20:33:07.323222] job release stage : copy_batchai_cached_logs completed...
# [2021-04-07T20:33:07.324033] job release stage : execute_job_release starting...
# [2021-04-07T20:33:07.325078] Entering context manager injector.
# [2021-04-07T20:33:07.349558] job release stage : upload_datastore completed...
# [2021-04-07T20:33:07.530838] job release stage : send_run_telemetry starting...
# [2021-04-07T20:33:07.532669] job release stage : execute_job_release completed...
# [2021-04-07T20:33:07.803753] get vm size and vm region successfully.
# [2021-04-07T20:33:08.258719] get compute meta data successfully.
# [2021-04-07T20:33:08.396843] post artifact meta request successfully.
# [2021-04-07T20:33:08.425976] upload compute record artifact successfully.
# [2021-04-07T20:33:08.426067] job release stage : send_run_telemetry completed...
# [2021-04-07T20:33:08.426678] Job release is complete
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': 'a659116e-d4b6-4522-afd8-cfd77f667bbf', 'target': 'train-cluster', 'status': 'Completed', 'startTimeUtc': '2021-04-07T20:31:21.539673Z', 'endTimeUtc': '2021-04-07T20:33:18.706961Z', 'properties': {'ContentSnapshotId': 'f182ef6a-ffbf-4b49-83e3-f2cf7d0f662d', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '6ef40495-9929-4f1c-abec-b3dcef47bd94', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '0ef6bb17', 'azureml.pipelinerunid': '139fbc05-bf77-4cc6-9edd-24f76c3d08e5', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '4ce86086-252d-4364-a11e-cda81b5909b9'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_train', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'train-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'diabetes_train': {'dataLocation': {'dataset': {'id': '4ce86086-252d-4364-a11e-cda81b5909b9', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'diabetes_train', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.20.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_6b58dbe613c3339df345a5893a067fcb'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt': 'https://jtupitzaamlsa. ...
# StepRunId: cd539bad-c452-48d9-b34d-30a0f08ff739
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/cd539bad-c452-48d9-b34d-30a0f08ff739?wsid=/subscriptions/49c8fb06-83d0-410a-81dd-c687e23bd829/resourcegroups/mlops-rg/workspaces/mlops-aml-ws
# StepRun( Register Model ) Status: Queued
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt
# ========================================================================================================================
# 2021-04-07T20:33:33Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore
# 2021-04-07T20:33:34Z Starting output-watcher...
# 2021-04-07T20:33:34Z IsDedicatedCompute == False, starting polling for Low-Pri Preemption
# 2021-04-07T20:33:38Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-04-07T20:33:38Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_9bc95d0e9c4578baaca711aceb5ccff2
# Digest: sha256:5370c3a5a19ba9380083203765332516c53c51d4effd98ff898529ba91e83d1c
# Status: Image is up to date for jtupitzaamlcr.azurecr.io/azureml/azureml_9bc95d0e9c4578baaca711aceb5ccff2:latest
# jtupitzaamlcr.azurecr.io/azureml/azureml_9bc95d0e9c4578baaca711aceb5ccff2:latest
# 2021-04-07T20:33:39Z Check if container cd539bad-c452-48d9-b34d-30a0f08ff739 already exist exited with 0,
#
# aac678f58401c54a37ecbe6361027b4682622a2c862e7c70231a910052cea28a
# 2021-04-07T20:33:40Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-04-07T20:33:40Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-2f816a9d4dbb613a8fc0c12be3504560-c93d49787693e5f2-01 -sshRequired=false]
# 2021/04/07 20:33:40 Starting App Insight Logger for task:  containerSetup
# 2021/04/07 20:33:40 Version: 3.0.01544.0003 Branch: .SourceBranch Commit: 14e0b35
# 2021/04/07 20:33:40 Entered ContainerSetupTask - Preparing infiniband
# 2021/04/07 20:33:40 Starting infiniband setup
# 2021/04/07 20:33:40 VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/04/07 20:33:40 VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-04-07T20:33:40Z VMSize: standard_ds2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/04/07 20:33:40 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/04/07 20:33:40 Not setting up Infiniband in Container
# 2021/04/07 20:33:40 Not setting up Infiniband in Container
# 2021-04-07T20:33:40Z Not setting up Infiniband in Container
# 2021/04/07 20:33:40 sshd inside container not required for job, skipping setup.
# 2021/04/07 20:33:40 All App Insights Logs was send successfully
# 2021/04/07 20:33:40 App Insight Client has already been closed
# 2021/04/07 20:33:40 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-04-07T20:33:40Z Starting docker container succeeded.
# 2021-04-07T20:33:46Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2021/04/07 20:33:32 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/04/07 20:33:32 Version: 3.0.01544.0003 Branch: .SourceBranch Commit: 14e0b35
# >>>   2021/04/07 20:33:32 runtime.GOOS linux
# >>>   2021/04/07 20:33:32 Checking if '/tmp' exists
# >>>   2021/04/07 20:33:32 Reading dyanamic configs
# >>>   2021/04/07 20:33:32 Container sas url: https://baiscriptseastusprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=gCpFfTbL8hPl%2BzV43hBdfOZC4SuKqZoJraIo10S4%2FYw%3D
# >>>   2021/04/07 20:33:32 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: not a directory
# >>>   2021/04/07 20:33:32 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed true, isEnable true,
# >>>   2021/04/07 20:33:32 azsecpack isEnable:true,GetDisableVsatlsscan:true
# >>>   2021/04/07 20:33:32 start to install azsecpack..., MachineName is d20c5f6b0cdd4691917a1cd25c0d7456000000
# >>>
# >>>   2021/04/07 20:33:32
# >>>   2021/04/07 20:33:32
# >>>   2021/04/07 20:33:32 OS patching disabled by dynamic configs. Skipping.
# >>>   2021/04/07 20:33:32 Job: AZ_BATCHAI_JOB_NAME does not turn on the DetonationChamber
# >>>   2021/04/07 20:33:32 Start to getting gpu count by running nvidia-smi command
# >>>   2021/04/07 20:33:32 GPU count found on the node: 0
# >>>   2021/04/07 20:33:32 AMLComputeXDSEndpoint:  https://eastus-prodk8ds.batchai.core.windows.net
# >>>   2021/04/07 20:33:32 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/04/07 20:33:32 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/config
# >>>   2021/04/07 20:33:32 This is not a aml-workstation (compute instance), current offer type: amlcompute. Starting identity responder as part of prepareJobEnvironment.
# >>>   2021/04/07 20:33:32 Starting identity responder.
# >>>   2021/04/07 20:33:32 Starting identity responder.
# >>>   2021/04/07 20:33:32 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2021/04/07 20:33:32 Logfile used for identity responder: /mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/IdentityResponderLog-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt
# >>>   2021/04/07 20:33:32 Logfile used for identity responder: /mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/IdentityResponderLog-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt
# >>>   2021/04/07 20:33:32 Started Identity Responder for job.
# >>>   2021/04/07 20:33:32 Started Identity Responder for job.
# >>>   2021/04/07 20:33:32 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/wd
# >>>   2021/04/07 20:33:32 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/shared
# >>>   2021/04/07 20:33:32 From the policy service, the filtering patterns is: , data store is
# >>>   2021/04/07 20:33:32 Mounting job level file systems
# >>>   2021/04/07 20:33:32 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts
# >>>   2021/04/07 20:33:32 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/config/.amlcompute.datastorecredentials
# >>>   2021/04/07 20:33:32 Datastore credentials file not found, skipping.
# >>>   2021/04/07 20:33:32 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/config/.master.runtimesastokens
# >>>   2021/04/07 20:33:32 Runtime sas tokens file not found, skipping.
# >>>   2021/04/07 20:33:32 No NFS configured
# >>>   2021/04/07 20:33:32 No Azure File Shares configured
# >>>   2021/04/07 20:33:32 Mounting blob file systems
# >>>   2021/04/07 20:33:32 Blobfuse runtime version 1.3.6
# >>>   2021/04/07 20:33:32 Mounting azureml-blobstore-cd212f55-2e2e-4eb0-a3b8-3ccb3bcb87cf container from jtupitzaamlsa account at /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore
# >>>   2021/04/07 20:33:32 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/04/07 20:33:32 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/04/07 20:33:32 Blobfuse cache size set to 8999 MB.
# >>>   2021/04/07 20:33:32 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=8999 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/04/07 20:33:32 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore
# >>>   2021/04/07 20:33:33 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore
# >>>   2021/04/07 20:33:34 Successfully mounted azureml-blobstore-cd212f55-2e2e-4eb0-a3b8-3ccb3bcb87cf container from jtupitzaamlsa account at /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore
# >>>   2021/04/07 20:33:34 No unmanaged file systems configured
# >>>   2021/04/07 20:33:34 Start to getting gpu count by running nvidia-smi command
# >>>   2021/04/07 20:33:34 From the policy service, the filtering patterns is: , data store is
# >>>   2021/04/07 20:33:34 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/azureml_compute_logs
# >>>   2021/04/07 20:33:34 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/logs
# >>>   2021/04/07 20:33:34 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/outputs
# >>>   2021/04/07 20:33:34 Starting output-watcher...
# >>>   2021/04/07 20:33:34 Single file input dataset is enabled.
# >>>   2021/04/07 20:33:34 Start to pulling docker image: jtupitzaamlcr.azurecr.io/azureml/azureml_9bc95d0e9c4578baaca711aceb5ccff2
# >>>   2021/04/07 20:33:34 Start pull docker image: jtupitzaamlcr.azurecr.io
# >>>   2021/04/07 20:33:34 Getting credentials for image jtupitzaamlcr.azurecr.io/azureml/azureml_9bc95d0e9c4578baaca711aceb5ccff2 with url jtupitzaamlcr.azurecr.io
# >>>   2021/04/07 20:33:34 Container registry is ACR.
# >>>   2021/04/07 20:33:34 Skip getting ACR Credentials from Identity and will be getting it from EMS
# >>>   2021/04/07 20:33:34 Getting ACR Credentials from EMS for environment diabetes-pipeline-env:1
# >>>   2021/04/07 20:33:34 Requesting XDS for registry details.
# >>>   2021/04/07 20:33:34 Attempt 1 of http call to https://eastus-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/49c8fb06-83d0-410a-81dd-c687e23bd829/resourceGroups/mlops-rg/workspaces/mlops-aml-ws/clusters/train-cluster/nodes/tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p?api-version=2018-02-01
# >>>   2021/04/07 20:33:37 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 15
# >>>   FilteredData: 0.
# >>>   2021/04/07 20:33:38 Got container registry details from credentials service for registry address: jtupitzaamlcr.azurecr.io.
# >>>   2021/04/07 20:33:38 Writing ACR Details to file...
# >>>   2021/04/07 20:33:38 Copying ACR Details file to worker nodes...
# >>>   2021/04/07 20:33:38 Executing 'Copy ACR Details file' on 10.0.0.4
# >>>   2021/04/07 20:33:38 Begin executing 'Copy ACR Details file' task on Node
# >>>   2021/04/07 20:33:38 'Copy ACR Details file' task Node result: succeeded
# >>>   2021/04/07 20:33:38 Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>   >>>
# >>>   >>>
# >>>   2021/04/07 20:33:38 Successfully retrieved ACR Credentials from EMS.
# >>>   2021/04/07 20:33:38 EMS returned jtupitzaamlcr.azurecr.io for environment diabetes-pipeline-env
# >>>   2021/04/07 20:33:38 start login to the docker registry
# >>>   2021/04/07 20:33:38 Successfully logged into the docker registry.
# >>>   2021/04/07 20:33:38 Start run pull docker image command
# >>>   2021/04/07 20:33:39 Pull docker image succeeded.
# >>>   2021/04/07 20:33:39 Pull docker image time: 5.016152055s
# >>>
# >>>   2021/04/07 20:33:39 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/04/07 20:33:39 Start to getting gpu count by running nvidia-smi command
# >>>   2021/04/07 20:33:39 Setting the memory limit for docker container to be 6618 MB
# >>>   2021/04/07 20:33:39 The env variable file size is 37445 bytes
# >>>   2021/04/07 20:33:39 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2021/04/07 20:33:39 Original Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,cd539bad-c452-48d9-b34d-30a0f08ff739,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/certs:/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/certs,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-m,6618m,-v,/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/azureml_compute_logs,-v,/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/wd:/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/wd,-v,/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739:/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739,-v,/mnt/batch/tasks/shared/LS_root/shared/tracing/cd539bad-c452-48d9-b34d-30a0f08ff739/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/cd539bad-c452-48d9-b34d-30a0f08ff739/logs/azureml/tracing,-w,/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/config/.batchai.envlist,--shm-size,2g
# >>>   2021/04/07 20:33:39 the binding /mnt/batch/tasks/shared/LS_root/shared/tracing/cd539bad-c452-48d9-b34d-30a0f08ff739/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/cd539bad-c452-48d9-b34d-30a0f08ff739/logs/azureml/tracing is discarded as we already have /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared
# >>>   2021/04/07 20:33:39 the binding /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/azureml_compute_logs is discarded as we already have /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739:/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739
# >>>   2021/04/07 20:33:39 Updated Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,cd539bad-c452-48d9-b34d-30a0f08ff739,-m,6618m,-w,/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/config/.batchai.envlist,--shm-size,2g,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739:/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739,-v,/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/wd:/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/wd,-v,/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/certs:/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/certs
# >>>   2021/04/07 20:33:39 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name cd539bad-c452-48d9-b34d-30a0f08ff739 -m 6618m -w /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/config/.batchai.envlist --shm-size 2g -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739:/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739 -v /mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/wd:/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/wd -v /mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/certs:/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/certs -d -it --privileged --net=host jtupitzaamlcr.azurecr.io/azureml/azureml_9bc95d0e9c4578baaca711aceb5ccff2
# >>>   2021/04/07 20:33:39 Check if container cd539bad-c452-48d9-b34d-30a0f08ff739 already exist exited with 0,
# >>>
# >>>   2021/04/07 20:33:39 Check if container cd539bad-c452-48d9-b34d-30a0f08ff739 already exist exited with 0,
# >>>
# >>>   2021/04/07 20:33:40 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/04/07 20:33:40 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/04/07 20:33:40 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-2f816a9d4dbb613a8fc0c12be3504560-c93d49787693e5f2-01 -sshRequired=false]
# >>>   2021/04/07 20:33:40 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-2f816a9d4dbb613a8fc0c12be3504560-c93d49787693e5f2-01 -sshRequired=false]
# >>>   2021/04/07 20:33:40 Container ssh is not required for job type.
# >>>   2021/04/07 20:33:40 Starting docker container succeeded.
# >>>   2021/04/07 20:33:40 Starting docker container succeeded.
# >>>   2021/04/07 20:33:40 Disk space after starting docker container: 10453MB
# >>>   2021/04/07 20:33:40 Begin execution of runSpecialJobTask
# >>>   2021/04/07 20:33:40 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/azureml_compute_logs
# >>>   2021/04/07 20:33:40 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_6b58dbe613c3339df345a5893a067fcb/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"f182ef6a-ffbf-4b49-83e3-f2cf7d0f662d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/04/07 20:33:40 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/azureml_compute_logs/65_job_prep-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt
# >>>   2021/04/07 20:33:40 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/azureml_compute_logs/65_job_prep-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt
# >>>   2021/04/07 20:33:40 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739;/azureml-envs/azureml_6b58dbe613c3339df345a5893a067fcb/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"f182ef6a-ffbf-4b49-83e3-f2cf7d0f662d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/04/07 20:33:41 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/04/07 20:33:41 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-2f816a9d4dbb613a8fc0c12be3504560-cd31deaf13188021-01 -t cd539bad-c452-48d9-b34d-30a0f08ff739 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/e0791806-a9ac-4549-8bca-6d8d34e90853/job-1/cd539bad-c452-48d9-b_5a1b46dc-9359-4bb1-9b97-1810049c1da6/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739;/azureml-envs/azureml_6b58dbe613c3339df345a5893a067fcb/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml-ws/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739/mounts/workspaceblobstore/azureml/cd539bad-c452-48d9-b34d-30a0f08ff739-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"f182ef6a-ffbf-4b49-83e3-f2cf7d0f662d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/04/07 20:33:42 Attempt 1 of http call to https://eastus.experiments.azureml.net/history/v1.0/private/subscriptions/49c8fb06-83d0-410a-81dd-c687e23bd829/resourceGroups/mlops-rg/providers/Microsoft.MachineLearningServices/workspaces/mlops-aml-ws/runs/cd539bad-c452-48d9-b34d-30a0f08ff739/spans
# >>>   2021/04/07 20:33:45 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:41.589656] Entering job preparation.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:43.149104] Starting job preparation.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:43.149146] Extracting the control code.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:43.175376] fetching and extracting the control code on master node.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:43.175421] Starting extract_project.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:43.175469] Starting to extract zip file.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:43.754743] Finished extracting zip file.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:43.979359] Using urllib.request Python 3.0 or later
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:43.979436] Start fetching snapshots.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:43.979491] Start fetching snapshot.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:43.979516] Retrieving project from snapshot: f182ef6a-ffbf-4b49-83e3-f2cf7d0f662d
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 48
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:44.446933] Finished fetching snapshot.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:44.446964] Finished fetching snapshots.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:44.447067] Finished extract_project.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:44.457287] Finished fetching and extracting the control code.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:44.460867] downloadDataStore - Download from datastores if requested.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:44.462492] Start run_history_prep.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:44.564226] Entering context manager injector.
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: Acquired lockfile /tmp/cd539bad-c452-48d9-b34d-30a0f08ff739-datastore.lock to downloading input data references
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:45.015933] downloadDataStore completed
# >>>   2021/04/07 20:33:45 runSpecialJobTask: preparation: [2021-04-07T20:33:45.019997] Job preparation is complete.
# >>>   2021/04/07 20:33:45 Execution of runSpecialJobTask completed
# >>>   2021/04/07 20:33:45 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/04/07 20:33:45 Process Exiting with Code:  0
# >>>   2021/04/07 20:33:45 All App Insights Logs was send successfully
# >>>
# 2021-04-07T20:33:46Z 127.0.0.1 slots=2 max-slots=2
# 2021-04-07T20:33:46Z launching Custom job
# Streaming azureml-logs/75_job_post-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt
# ===============================================================================================================
# [2021-04-07T20:33:57.662055] Entering job release
# [2021-04-07T20:33:58.688111] Starting job release
# [2021-04-07T20:33:58.693175] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 146
# [2021-04-07T20:33:58.693594] job release stage : upload_datastore starting...
# [2021-04-07T20:33:58.703091] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-04-07T20:33:58.703439] job release stage : copy_batchai_cached_logs starting...
# [2021-04-07T20:33:58.704063] job release stage : execute_job_release starting...
# [2021-04-07T20:33:58.704232] job release stage : copy_batchai_cached_logs completed...
# [2021-04-07T20:33:58.704835] Entering context manager injector.
# [2021-04-07T20:33:58.723013] job release stage : upload_datastore completed...
# [2021-04-07T20:33:58.863273] job release stage : send_run_telemetry starting...
# [2021-04-07T20:33:59.066760] get vm size and vm region successfully.
# [2021-04-07T20:33:59.344132] get compute meta data successfully.
# [2021-04-07T20:33:59.569932] post artifact meta request successfully.
# [2021-04-07T20:33:59.612018] job release stage : execute_job_release completed...
# [2021-04-07T20:33:59.621295] upload compute record artifact successfully.
# [2021-04-07T20:33:59.621439] job release stage : send_run_telemetry completed...
# [2021-04-07T20:33:59.621838] Job release is complete
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': 'cd539bad-c452-48d9-b34d-30a0f08ff739', 'target': 'train-cluster', 'status': 'Completed', 'startTimeUtc': '2021-04-07T20:33:34.263651Z', 'endTimeUtc': '2021-04-07T20:34:12.314564Z', 'properties': {'ContentSnapshotId': 'f182ef6a-ffbf-4b49-83e3-f2cf7d0f662d', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '684f2a55-bea4-471c-b5fd-c98d4aaca80b', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '1c29e350', 'azureml.pipelinerunid': '139fbc05-bf77-4cc6-9edd-24f76c3d08e5', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'register_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'train-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.20.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_6b58dbe613c3339df345a5893a067fcb'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt': 'https://jtupitzaamlsa.blob.core.windows.net/azureml/ExperimentRun/dcid.cd539bad-c452-48d9-b34d-30a0f08ff739/azureml-logs/55_azureml-execution-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt?sv=2019-02-02&sr=b&sig=YIoOaVvvIZCH5taRpOeVyckBonQvCNGWugGPOUyMP7I%3D&st=2021-04-07T20%3A24%3A01Z&se=2021-04-08T04%3A34%3A01Z&sp=r', 'azureml-logs/65_job_prep-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d0 ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '139fbc05-bf77-4cc6-9edd-24f76c3d08e5', 'status': 'Completed', 'startTimeUtc': '2021-04-07T20:26:50.174683Z', 'endTimeUtc': '2021-04-07T20:34:13.790882Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://jtupitzaamlsa.blob.core.windows.net/azureml/ExperimentRun/dcid.139fbc05-bf77-4cc6-9edd-24f76c3d08e5/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=a9UprFA8Ds6TUBBruot4yMhhRJzblwjs7Bvr1357iVk%3D&st=2021-04-07T20%3A24%3A15Z&se=2021-04-08T04%3A34%3A15Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://jtupitzaamlsa.blob.core.windows.net/azureml/ExperimentRun/dcid.139fbc05-bf77-4cc6-9edd-24f76c3d08e5/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=3zXKrLtHi5%2BWc8KqBqzVHQX5zxrvUiC9gswb6SI0l%2Bs%3D&st=2021-04-07T20%3A24%3A15Z&se=2021-04-08T04%3A34%3A15Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://jtupitzaamlsa.blob.core.windows.net/azureml/ExperimentRun/dcid.139fbc05-bf77-4cc6-9edd-24f76c3d08e5/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=Q7C9GBFLrHQi%2FYN07L3wi7rG5mVbK1gosbzAmqMJYDU%3D&st=2021-04-07T20%3A24%3A15Z&se=2021-04-08T04%3A34%3A15Z&sp=r'}, 'submittedBy': 'Jon Tupitza'}
# 'Finished'

# %% [markdown]
# ### Verify that the Newly Trained Model Exists
# A new model should be registered with a Training context tag indicating it was trained in a pipeline.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 2
# 	 Training context : Pipeline
#
#
# diabetes_model version: 1
# 	 Training context : Pipeline
#
#
# porto_seguro_safe_driver_model version: 24
#
#
# porto_seguro_safe_driver_model version: 23
#
#
# porto_seguro_safe_driver_model.pkl version: 6
#
#
# porto_seguro_safe_driver_model version: 22
#
#
# porto_seguro_safe_driver_model version: 21
#
#
# diabetes_regression_model.pkl version: 1
# 	 area : diabetes_regression
# 	 run_id : 6ea0258d-ebb1-451b-aec0-187aef0a20f3
# 	 experiment_name : mlopspython
# 	 mse : 3295.741064355809
# 	 BuildId : 26
# 	 BuildUri : https://dev.azure.com/jtupitza-msft/python-mlops/_build/results?buildId=26

# %% [markdown]
# ### Publish the Pipeline as a REST Service

# %%
published_pipeline = pipeline.publish(name="Diabetes_Training_Pipeline",
                                      description="Trains diabetes model",
                                      version="1.0")
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/49c8fb06-83d0-410a-81dd-c687e23bd829/resourceGroups/mlops-rg/providers/Microsoft.MachineLearningServices/workspaces/mlops-aml-ws/PipelineRuns/PipelineSubmit/b3f8f29c-5222-4944-9d9d-f41a2124fe3e

# %% [markdown]
# ### Test the New REST Service Endpoint
# - Use the authorization header from the current Azure workspace connection to authenticate the call to the REST Service.
# - Since the pipeline runs asynchronously, an identifier is returned that can be used to track the experiment at runtime.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %%
import requests
from azureml.pipeline.core.run import PipelineRun

experiment_name = 'Run-diabetes-pipeline'

response = requests.post(rest_endpoint, headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()["Id"]
print("Tracking Run: ", run_id)

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: fa02c5cd-75bc-4aa7-b593-12561d977630
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Run-diabetes-pipeline/runs/fa02c5cd-75bc-4aa7-b593-12561d977630?wsid=/subscriptions/49c8fb06-83d0-410a-81dd-c687e23bd829/resourcegroups/mlops-rg/workspaces/mlops-aml-ws
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 0335f780-42e8-4e66-8095-d4e35d858cbf
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Run-diabetes-pipeline/runs/0335f780-42e8-4e66-8095-d4e35d858cbf?wsid=/subscriptions/49c8fb06-83d0-410a-81dd-c687e23bd829/resourcegroups/mlops-rg/workspaces/mlops-aml-ws
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': '0335f780-42e8-4e66-8095-d4e35d858cbf', 'target': 'train-cluster', 'status': 'Completed', 'startTimeUtc': '2021-04-07T20:36:32.279888Z', 'endTimeUtc': '2021-04-07T20:36:32.713888Z', 'properties': {'azureml.reusedrunid': 'a659116e-d4b6-4522-afd8-cfd77f667bbf', 'azureml.reusednodeid': '0ef6bb17', 'azureml.reusedpipeline': '139fbc05-bf77-4cc6-9edd-24f76c3d08e5', 'azureml.reusedpipelinerunid': '139fbc05-bf77-4cc6-9edd-24f76c3d08e5', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '0ef6bb17', 'ContentSnapshotId': 'f182ef6a-ffbf-4b49-83e3-f2cf7d0f662d', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '6ef40495-9929-4f1c-abec-b3dcef47bd94', 'azureml.pipelinerunid': 'fa02c5cd-75bc-4aa7-b593-12561d977630', 'azureml.pipelineid': 'b3f8f29c-5222-4944-9d9d-f41a2124fe3e', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'train-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'diabetes_train': {'dataLocation': {'dataset': {'id': '4ce86086-252d-4364-a11e-cda81b5909b9', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'diabetes_train', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.20.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_6b58dbe613c3339df345a5893a067fcb'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}}, 'logFiles ...
# StepRunId: 393c267e-9825-4d11-bc4b-112623780d8c
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Run-diabetes-pipeline/runs/393c267e-9825-4d11-bc4b-112623780d8c?wsid=/subscriptions/49c8fb06-83d0-410a-81dd-c687e23bd829/resourcegroups/mlops-rg/workspaces/mlops-aml-ws
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': '393c267e-9825-4d11-bc4b-112623780d8c', 'target': 'train-cluster', 'status': 'Completed', 'startTimeUtc': '2021-04-07T20:36:35.198617Z', 'endTimeUtc': '2021-04-07T20:36:35.704468Z', 'properties': {'azureml.reusedrunid': 'cd539bad-c452-48d9-b34d-30a0f08ff739', 'azureml.reusednodeid': '1c29e350', 'azureml.reusedpipeline': '139fbc05-bf77-4cc6-9edd-24f76c3d08e5', 'azureml.reusedpipelinerunid': '139fbc05-bf77-4cc6-9edd-24f76c3d08e5', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '1c29e350', 'ContentSnapshotId': 'f182ef6a-ffbf-4b49-83e3-f2cf7d0f662d', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '684f2a55-bea4-471c-b5fd-c98d4aaca80b', 'azureml.pipelinerunid': 'fa02c5cd-75bc-4aa7-b593-12561d977630', 'azureml.pipelineid': 'b3f8f29c-5222-4944-9d9d-f41a2124fe3e', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'register_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'train-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/a659116e-d4b6-4522-afd8-cfd77f667bbf/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.20.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_6b58dbe613c3339df345a5893a067fcb'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_9d59c075601fa673d7bb6b8a9e5d44a7505ed8b23f738d007c500f119c525b9a_p.txt': 'https://jtupitzaamlsa.blob.core.windows.net/azureml/ExperimentRun/dcid.cd539bad-c452-48d9-b34d-30a0f08ff739/azureml-logs/55_azureml-e ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'fa02c5cd-75bc-4aa7-b593-12561d977630', 'status': 'Completed', 'startTimeUtc': '2021-04-07T20:36:29.514418Z', 'endTimeUtc': '2021-04-07T20:36:37.918434Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': 'b3f8f29c-5222-4944-9d9d-f41a2124fe3e'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://jtupitzaamlsa.blob.core.windows.net/azureml/ExperimentRun/dcid.fa02c5cd-75bc-4aa7-b593-12561d977630/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=6IvRhhLByUgIO9JSkW8uzz%2FDgRlqGfrZskiURRg%2FfNk%3D&st=2021-04-07T20%3A26%3A40Z&se=2021-04-08T04%3A36%3A40Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://jtupitzaamlsa.blob.core.windows.net/azureml/ExperimentRun/dcid.fa02c5cd-75bc-4aa7-b593-12561d977630/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=1asAlgH99CcJtxV53c5BMSJcLXzmg85CCE8pTyTvi8Q%3D&st=2021-04-07T20%3A26%3A40Z&se=2021-04-08T04%3A36%3A40Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://jtupitzaamlsa.blob.core.windows.net/azureml/ExperimentRun/dcid.fa02c5cd-75bc-4aa7-b593-12561d977630/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=o%2Bgg1%2BevkUE%2FtRsay8eDFCh3pEjSCfgmKiAAURU%2FN0o%3D&st=2021-04-07T20%3A26%3A40Z&se=2021-04-08T04%3A36%3A40Z&sp=r'}, 'submittedBy': 'Jon Tupitza'}
#
# Tracking Run:  fa02c5cd-75bc-4aa7-b593-12561d977630
